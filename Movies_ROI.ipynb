# %% [markdown]
# # Importing necessary modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("danielgrijalvas/movies")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/movies

# %%
movies = pd.read_csv("/kaggle/input/movies/movies.csv") #reading the dataset

# %% [markdown]
# # Exploration

# %%
movies.sample(10) # having a look at the dataset
# Out:
#                                        name     rating   genre  year  \
# 1543              The Return of Swamp Thing      PG-13  Action  1989
# 731                         Trouble in Mind          R  Comedy  1985
# 4450  Eternal Sunshine of the Spotless Mind          R   Drama  2004
# 5601                           Love Happens      PG-13   Drama  2009
# 3736                          Drowning Mona      PG-13  Comedy  2000
# 2392                                   Kika    Unrated  Comedy  1993
# 3269                      The Mask of Zorro      PG-13  Action  1998
# 3526                          Runaway Bride         PG  Comedy  1999
# 786                            Taipei Story  Not Rated   Drama  1985
# 6559                         A Little Chaos          R   Drama  2014
#
#                                 released  score     votes         director  \
# 1543        May 12, 1989 (United States)    4.7    4400.0     Jim Wynorski
# 731           March 1986 (United States)    6.5    1800.0     Alan Rudolph
# 4450      March 19, 2004 (United States)    8.3  935000.0    Michel Gondry
# 5601  September 18, 2009 (United States)    5.7   32000.0     Brandon Camp
# 3736       March 3, 2000 (United States)    5.7   14000.0       Nick Gomez
# 2392         May 6, 1994 (United States)    6.5   13000.0  Pedro Almodóvar
# 3269       July 17, 1998 (United States)    6.8  173000.0  Martin Campbell
# 3526       July 30, 1999 (United States)    5.6   95000.0   Garry Marshall
# 786                        1985 (Taiwan)    7.7    2500.0      Edward Yang
# 6559       June 26, 2015 (United States)    6.5   22000.0     Alan Rickman
#
#                  writer                star         country      budget  \
# 1543      Neil Cuthbert         Dick Durock   United States   4000000.0
# 731        Alan Rudolph  Kris Kristofferson   United States         NaN
# 4450    Charlie Kaufman          Jim Carrey   United States  20000000.0
# 5601       Brandon Camp    Jennifer Aniston   United States  18000000.0
# 3736    Peter Steinfeld        Danny DeVito   United States  37000000.0
# 2392    Pedro Almodóvar        Peter Coyote           Spain         NaN
# 3269  Johnston McCulley    Antonio Banderas   United States  95000000.0
# 3526    Josann McGibbon       Julia Roberts   United States  70000000.0
# 786       T'ien-wen Chu           Chin Tsai          Taiwan         NaN
# 6559       Jeremy Brock        Kate Winslet  United Kingdom         NaN
#
#             gross                      company  runtime
# 1543     192816.0      Lightyear Entertainment     88.0
# 731       19632.0  Pfeiffer/Blocker Production    111.0
# 4450   74036715.0               Focus Features    108.0
# 5601   36088028.0           Universal Pictures    109.0
# 3736   15910104.0           Code Entertainment     96.0
# 2392    2019581.0                     El Deseo    114.0
# 3269  250288523.0             TriStar Pictures    136.0
# 3526  309460292.0           Paramount Pictures    116.0
# 786       35336.0       Evergreen Film Company    119.0
# 6559   10084623.0                    BBC Films    112.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# ***From looking at the number of non null values we can assume that there are multiple missing data points***
#
#
#
# ---

# %% [markdown]
# # Cleaning the Dataset

# %%
movies.isna().sum() #counting the number of missing values in each column
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
sum((movies['budget'] == 0) & (movies['gross'] == 0)) # checking a case where movie budget and revenue is both 0
# Out:
# 0

# %%
sum(movies['budget'] == 0) #counting the number of cases where budget is 0
# Out:
# 0

# %%
sum(movies['gross'] == 0) #counting the number of cases where revenue is 0
# Out:
# 0

# %%
movies.dropna(subset = ['runtime', 'released', 'star', 'country', 'votes', 'writer', 'budget', 'gross', 'company', 'rating'], inplace = True) #dropping the rest of the missing values

# %%
movies.isna().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
movies['ROI (in %)'] = ((movies['gross'] - movies['budget'])/movies['budget'])*100 #creating a new feature to calculate the ROI

# %%
movies['Profit Margin (in %)'] = ((movies['gross'] - movies['budget'])/movies['gross'])*100 #creating a new feature to calculate the profit margin

# %%
movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime   ROI (in %)  Profit Margin (in %)
# 0   46998772.0        Warner Bros.    146.0   147.361958             59.573412
# 1   58853106.0   Columbia Pictures    104.0  1207.846800             92.353845
# 2  538375067.0           Lucasfilm    124.0  2890.972594             96.656606
# 3   83453539.0  Paramount Pictures     88.0  2284.386829             95.806050
# 4   39846344.0      Orion Pictures     98.0   564.105733             84.942157

# %%
# movies.to_csv("movies_cleaned.csv", index=False) #to save the new updated dataset
